# %%
import pandas as pd

# %%
df = pd.read_csv('logs/run_2025-12-23_12-37-10/upskill_plans.csv')f

# %%
pd.set_option('display.max_colwidth', None)

# %%
df
# Out:
#   student_id decision  \
# 0       S001   REJECT
# 1       S003   REJECT
# 2       S006   REJECT
# 3       S008   REJECT
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                         recommendation
# ...

# %%
ffcกกกdddก
